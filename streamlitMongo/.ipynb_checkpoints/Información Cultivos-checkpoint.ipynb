# %%
import pandas as pd
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://germancastano:pT1U3pSkrtyjPGLJ@datasetprueba.1nmab.mongodb.net/?retryWrites=true&w=majority&appName=DataSetPrueba"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
# https://www.kaggle.com/datasets/raghavramasamy/crop-statistics-fao-all-countries?select=Crops_AllData_Normalized.csv
dfDatos = pd.read_csv("./Crops_AllData_Normalized.csv",encoding="latin1")

# %%
dfDatos[dfDatos["Area Code"]<5000]
# Out:
#          Area Code         Area  Item Code                 Item  Element Code  \
# 0                2  Afghanistan        221  Almonds, with shell          5312
# 1                2  Afghanistan        221  Almonds, with shell          5312
# 2                2  Afghanistan        221  Almonds, with shell          5312
# 3                2  Afghanistan        221  Almonds, with shell          5312
# 4                2  Afghanistan        221  Almonds, with shell          5312
# ...            ...          ...        ...                  ...           ...
# 1806383        181     Zimbabwe       1735   Vegetables Primary          5510
# 1806384        181     Zimbabwe       1735   Vegetables Primary          5510
# 1806385        181     Zimbabwe       1735   Vegetables Primary          5510
# 1806386        181     Zimbabwe       1735   Vegetables Primary          5510
# 1806387        181     Zimbabwe       1735   Vegetables Primary          5510
#
# ...

# %%
len(dfDatos[dfDatos["Area Code"]<5000])
# Out:
# 1806388

# %%
db = client["datasetCrops"]
# collection = db["empleoGral"]
# data =dfDatosGeneral.to_dict("records")
# collection.drop()
# collection.insert_many(data)

# db = client["673eacb652d8210aedcbbc4c"]
collection = db["crops"]
data =dfDatos[dfDatos["Area Code"]<5000].to_dict("records")
collection.drop()
collection.insert_many(data)

# %%
cursor = collection.find()
list_cur = list(cursor)
df = pd.DataFrame(list_cur)
